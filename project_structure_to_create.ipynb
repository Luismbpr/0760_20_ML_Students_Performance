# %%
import os
import sys
from pathlib import Path
import logging

# %%
import os
from pathlib import Path
import logging

logging.basicConfig(level=logging.INFO, format='[%(asctime)s]: %(message)s:')

PROJECT_FILE_PATH="/Users/luis/Documents/Programming/dev/0760 Complete MLOps Bootcamp With 10 Plus End To End ML Projects Krish Naik/venv_0760_Complete_MLOps_Bootcamp_Krish_Naik_312_01/0760_Course/Section 20 End To End DS Project implementation With Mulitple AWS, Azure Deployment/0760_20_01_ML_Students_Performance/"


list_of_folders=[
    #f"{PROJECT_FILE_PATH}/.env",
    #f"{PROJECT_FILE_PATH}/.gitignore",
    #f"{PROJECT_FILE_PATH}/__init__.py",
    #f"{PROJECT_FILE_PATH}/README.md",
    #f"{PROJECT_FILE_PATH}/app.py",
    #f"{PROJECT_FILE_PATH}/requirements.txt",
    #f"{PROJECT_FILE_PATH}/setup.py",
    ###,
    f"{PROJECT_FILE_PATH}/artifacts/",
    ##f"{PROJECT_FILE_PATH}/artifacts/__init__.py",
    ###,
    f"{PROJECT_FILE_PATH}/notebook/",
    #f"{PROJECT_FILE_PATH}/notebook/Project_EDA_001_001.ipynb",
    #f"{PROJECT_FILE_PATH}/notebook/Project_EDA_002_001.ipynb",
    #f"{PROJECT_FILE_PATH}/notebook/Project_Model_Training.ipynb",
    #f"{PROJECT_FILE_PATH}/notebook/procedures/project_001_001.ipynb",
    #f"{PROJECT_FILE_PATH}/notebook/procedures/project_002_001.ipynb",
    #f"{PROJECT_FILE_PATH}/notebook/procedures/Project_003_001.ipynb",
    ## /notebook/data/ will hold the raw data csv files,
    f"{PROJECT_FILE_PATH}/notebook/data/",
    #f"{PROJECT_FILE_PATH}/notebook/data/students_performance_0760.csv",
    ###,
    f"{PROJECT_FILE_PATH}/src/",
    #f"{PROJECT_FILE_PATH}/src/__init__.py",
    #f"{PROJECT_FILE_PATH}/src/exception.py",
    #f"{PROJECT_FILE_PATH}/src/logger.py",
    #f"{PROJECT_FILE_PATH}/src/utils.py",
    #,
    f"{PROJECT_FILE_PATH}/src/components/",
    #f"{PROJECT_FILE_PATH}/src/components/__init__.py",
    #f"{PROJECT_FILE_PATH}/src/components/data_gathering.py",
    #f"{PROJECT_FILE_PATH}/src/components/data_ingestion.py",
    #f"{PROJECT_FILE_PATH}/src/components/data_transformation.py",
    #f"{PROJECT_FILE_PATH}/src/components/model_trainer.py",
    #,
    f"{PROJECT_FILE_PATH}/src/pipeline/",
    #f"{PROJECT_FILE_PATH}/src/pipeline/__init__.py",
    #f"{PROJECT_FILE_PATH}/src/pipeline/predict_pipeline.py",
    #f"{PROJECT_FILE_PATH}/src/pipeline/train_pipeline.py",
    ###,
    f"{PROJECT_FILE_PATH}/templates/",
    #f"{PROJECT_FILE_PATH}/templates/home.html",
    #f"{PROJECT_FILE_PATH}/templates/index.html",
]


list_of_files=[
    #f"{PROJECT_FILE_PATH}/.env",
    #f"{PROJECT_FILE_PATH}/.gitignore",
    f"{PROJECT_FILE_PATH}/__init__.py",
    #f"{PROJECT_FILE_PATH}/README.md",
    f"{PROJECT_FILE_PATH}/app.py",
    #f"{PROJECT_FILE_PATH}/requirements.txt",
    f"{PROJECT_FILE_PATH}/setup.py",
    ###,
    #f"{PROJECT_FILE_PATH}/artifacts/",
    ##f"{PROJECT_FILE_PATH}/artifacts/__init__.py",
    ###,
    #f"{PROJECT_FILE_PATH}/notebook/",
    f"{PROJECT_FILE_PATH}/notebook/Project_EDA_001_001.ipynb",
    f"{PROJECT_FILE_PATH}/notebook/Project_EDA_002_001.ipynb",
    f"{PROJECT_FILE_PATH}/notebook/Project_Model_Training.ipynb",
    f"{PROJECT_FILE_PATH}/notebook/procedures/project_001_001.ipynb",
    f"{PROJECT_FILE_PATH}/notebook/procedures/project_002_001.ipynb",
    f"{PROJECT_FILE_PATH}/notebook/procedures/Project_003_001.ipynb",
    ## /notebook/data/ will hold the raw data csv files,
    #f"{PROJECT_FILE_PATH}/notebook/data/",
    #f"{PROJECT_FILE_PATH}/notebook/data/students_performance_0760.csv",
    ###,
    #f"{PROJECT_FILE_PATH}/src/",
    f"{PROJECT_FILE_PATH}/src/__init__.py",
    f"{PROJECT_FILE_PATH}/src/exception.py",
    f"{PROJECT_FILE_PATH}/src/logger.py",
    f"{PROJECT_FILE_PATH}/src/utils.py",
    #,
    #f"{PROJECT_FILE_PATH}/src/components/",
    f"{PROJECT_FILE_PATH}/src/components/__init__.py",
    f"{PROJECT_FILE_PATH}/src/components/data_gathering.py",
    f"{PROJECT_FILE_PATH}/src/components/data_ingestion.py",
    f"{PROJECT_FILE_PATH}/src/components/data_transformation.py",
    f"{PROJECT_FILE_PATH}/src/components/model_trainer.py",
    #,
    #f"{PROJECT_FILE_PATH}/src/pipeline/",
    f"{PROJECT_FILE_PATH}/src/pipeline/__init__.py",
    f"{PROJECT_FILE_PATH}/src/pipeline/predict_pipeline.py",
    f"{PROJECT_FILE_PATH}/src/pipeline/train_pipeline.py",
    ###,
    #f"{PROJECT_FILE_PATH}/templates/",
    f"{PROJECT_FILE_PATH}/templates/home.html",
    f"{PROJECT_FILE_PATH}/templates/index.html",
]


#list_of_folders
#list_of_files

## Create folders
for filepath in list_of_folders:
    filepath = Path(filepath)
    #filedir, filename = os.path.split(filepath)
    #print(f"filedir: {filedir}")
    #print(f"filename: {filename}")
    if filepath != "":
        os.makedirs(filepath, exist_ok=True)
        logging.info(f"Creating directory {filepath}")# for the file: {filename}")
    #if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
        #with open(filepath, "w") as f:
            #pass
            #logging.info(f"Creating empty file: {filepath}")
    else:
        logging.info(f"{filepath} already exists")
    

for filepath in list_of_files:
    filepath = Path(filepath)
    filedir, filename = os.path.split(filepath)
    print(f"filedir: {filedir}")
    print(f"filename: {filename}")
    if filedir != "":
        os.makedirs(filedir, exist_ok=True)
        logging.info(f"Creating directory {filedir} for the file: {filename}")
    if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
        with open(filepath, "w") as f:
            pass
            logging.info(f"Creating empty file: {filepath}")
    else:
        logging.info(f"{filename} already exists")
    


## for file creation
#for filepath in list_of_files:
#    filepath = Path(filepath)
#    filedir, filename=os.path.split(filepath)
#    
#
#    if filedir != "":
#        os.makedirs(filedir, exist_ok=True)
#        logging.info(f"Creating directory {filedir} for the file: {filename}")
#    
#    ## If the filepath does not exist, get the size of the filepath and if it is 0
#    ## Open filepath in write mode and create that file
#    if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
#        with open(filepath, "w") as f:
#            pass
#            logging.info(f"Creating empty file: {filepath}")
#    else:
#        logging.info(f"{filename} already exists")
# Out:
# [2025-04-03 18:18:24,310]: Creating directory /Users/luis/Documents/Programming/dev/0760 Complete MLOps Bootcamp With 10 Plus End To End ML Projects Krish Naik/venv_0760_Complete_MLOps_Bootcamp_Krish_Naik_312_01/0760_Course/Section 20 End To End DS Project implementation With Mulitple AWS, Azure Deployment/0760_20_01_ML_Students_Performance/artifacts:
# [2025-04-03 18:18:24,310]: Creating directory /Users/luis/Documents/Programming/dev/0760 Complete MLOps Bootcamp With 10 Plus End To End ML Projects Krish Naik/venv_0760_Complete_MLOps_Bootcamp_Krish_Naik_312_01/0760_Course/Section 20 End To End DS Project implementation With Mulitple AWS, Azure Deployment/0760_20_01_ML_Students_Performance/notebook:
# ...
