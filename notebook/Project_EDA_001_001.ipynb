# %% [markdown]
# # EDA - Part 001
# Dataset(s) - Students Performance

# %% [markdown]
# ### Dataset Information
#
# #### Dataset feature general description
# The variables that will be taken into account are the following:
#
# | Feature Name | Dataset Feature description | Possible Values in Dataset |
# |--|--|--|
# | Gender | Student gender | Male, Female |
# | Race ethnicity | Student ethnicity | Group A, B, C, D, E |
# | Parental level of Education | The level of education of the student's parents| some high school, high school, associate's degree, bachelor's degree, some college, master's degree|
# | Lunch | - Whether the student had lunch or not before taking the tests| standard, reduced/free, None |
# | Test Preparation Course | Whether a student had completed a test preparation course or not. | None, completed |
# | Math score | A math test score | score from 0 to 100 |
# | Reading score | A reading test score | score from 0 to 100 |
# | Writing score | A writing test score | score from 0 to 100 |

# %% [markdown]
# Data Checks to perform
# - Missing Values
# - Duplicates
# - Data Type
# - Number of unique values in each column
# - Statistics of current dataset
# - Various categories present in categorical columns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/Users/luis/Documents/Programming/dev/0760 Complete MLOps Bootcamp With 10 Plus End To End ML Projects Krish Naik/venv_0760_Complete_MLOps_Bootcamp_Krish_Naik_312_01/0760_Course/Section 20 End To End DS Project implementation With Mulitple AWS, Azure Deployment/0760_20_01_ML_Students_Performance/notebook/data/students_performance_0760.csv")
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
for column in df.columns:
    #print(column)
    print(df[column].value_counts())
    print("\n")
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64
#
#
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
#
#
# parental_level_of_education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
#
#
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64
#
#
# test_preparation_course
# none         642
# completed    358
# Name: count, dtype: int64
#
#
# math_score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64
#
#
# reading_score
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: count, Length: 72, dtype: int64
#
#
# writing_score
# ...

# %% [markdown]
# Data Checks to perform
# - **Missing Values**
# - **Duplicates**
# - Data Type
# - Number of unique values in each column
# - Statistics of current dataset
# - Various categories present in categorical columns

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data Checks to perform
# - Missing Values
# - Duplicates
# - **Data Type**
# - Number of unique values in each column
# - Statistics of current dataset
# - Various categories present in categorical columns

# %%
df.info()
print("\n")

for column in df.columns:
    #print(column)
    print(df[column].value_counts())
    print(df[column].dtype)
    print(df[column].dtypes)
    #print(type(df[column]))
    print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
#
#
# gender
# female    518
# male      482
# Name: count, dtype: int64
# object
# object
#
#
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
# object
# object
#
#
# ...

# %% [markdown]
# | # |  Column                       | Non-Null Count | Dtype |
# |--|--|--|--|
# | 0 |  gender                       | 1000 non-null  | object|
# | 1 |  race_ethnicity               | 1000 non-null  | object|
# | 2 |  parental_level_of_education  | 1000 non-null  | object|
# | 3 |  lunch                        | 1000 non-null  | object|
# | 4 |  test_preparation_course      | 1000 non-null  | object|
# | 5 |  math_score                   | 1000 non-null  | int64 |
# | 6 |  reading_score                | 1000 non-null  | int64 |
# | 7 |  writing_score                | 1000 non-null  | int64 |
#
# | Column | Feature Examples | Dtype |
# |--|--|--|
# | gender | female,male | dtype: object |
# | race_ethnicity | group C, group D, group B, group E, group A | dtype: object |
# | parental_level_of_education | some college, associate's degree, high school, some high school, bachelor's degree, master's degree | dtype: object |
# | lunch | standard,free/reduced | dtype: object |
# | test_preparation_course | none,completed | dtype: object |
# | test_preparation_course | none,completed | dtype: object |
# | math_score | 35,32,27,...,1 | dtype: int64 |
# | reading_score | 33,32,30,...,1 | dtype: int64 |
# | writing_score | 31,28,27,...,1 | dtype: int64 |

# %% [markdown]
# Data Checks to perform
# - Missing Values
# - Duplicates
# - Data Type
# - **Number of unique values in each column**
# - Statistics of current dataset
# - Various categories present in categorical columns

# %%
df.nunique().keys()
#df.nunique().values
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# Data Checks to perform
# - Missing Values
# - Duplicates
# - Data Type
# - Number of unique values in each column
# - **Statistics of current dataset**
# - Various categories present in categorical columns

# %%
## There are three numerical features
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
## There are three numerical features
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
q4_math, q3_math, q2_math, q1_math = np.percentile(df[['math_score']], [100, 75, 50, 25])
#q1_math, q2_math, q3_math, q4_math

q4_reading, q3_reading, q2_reading, q1_reading = np.percentile(df[['reading_score']], [100, 75, 50, 25])
#q1_reading, q2_reading, q3_reading, q4_reading

q4_writing, q3_writing, q2_writing, q1_writing = np.percentile(df[['writing_score']], [100, 75, 50, 25])
q1_writing, q2_writing, q3_writing, q4_writing
# Out:
# (57.75, 69.0, 79.0, 100.0)

# %%
#fig, axes = plt.subplot(ncols=3, nrows=1, figsize=(8,6), layout="constrained")

plt.boxplot(x=df[['math_score','reading_score','writing_score']], orientation='horizontal',)

plt.show()

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['math_score'].quantile(q=[0.01, 0.10, 0.25, 0.5, 0.75, 0.90, 1.0])
# Out:
# 0.01     27.99
# 0.10     47.00
# 0.25     57.00
# 0.50     66.00
# 0.75     77.00
# 0.90     86.00
# 1.00    100.00
# Name: math_score, dtype: float64

# %%
q1_math_02,q2_math_02, q3_math_02 = df['math_score'].quantile(q=[0.25, 0.50, 0.75])

plt.boxplot(x=df['math_score'])
print(f"There seems to be {q3_math_02-q1_math_02} outliers.")
plt.show()
# Out:
# There seems to be 20.0 outliers.

# %%
print("Categories in 'gender' variable:     ",end=" " )
print(df['gender'].unique())

print("Categories in 'race_ethnicity' variable:  ",end=" ")
print(df['race_ethnicity'].unique())

print("Categories in'parental level of education' variable:",end=" " )
print(df['parental_level_of_education'].unique())

print("Categories in 'lunch' variable:     ",end=" " )
print(df['lunch'].unique())

print("Categories in 'test preparation course' variable:     ",end=" " )
print(df['test_preparation_course'].unique())
# Out:
# Categories in 'gender' variable:      ['female' 'male']
# Categories in 'race_ethnicity' variable:   ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in'parental level of education' variable: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in 'lunch' variable:      ['standard' 'free/reduced']
# Categories in 'test preparation course' variable:      ['none' 'completed']

# %%
## There are three numerical features
#score_means = df.describe().T['mean'].T
#score_means
#score_medians = df.describe().T['50%'].T
#score_medians
#df_stats = pd.DataFrame([score_means, score_medians], index=['mean', 'median']).transpose()
#df_stats
df_stats = df.describe().loc[['mean', '50%', 'std']]#.transpose()
print(df_stats)
# Out:
#       math_score  reading_score  writing_score
# mean    66.08900      69.169000      68.054000
# 50%     66.00000      70.000000      69.000000
# std     15.16308      14.600192      15.195657

# %%
## Categorical variables
df.describe(include='O')#.loc['unique']
# Out:
#         gender race_ethnicity parental_level_of_education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test_preparation_course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %% [markdown]
# There seems to be some outliers on the lower side of the spectrum for the three test scores.
#
#       math_score  reading_score  writing_score
# mean    66.08900      69.169000      68.054000
# 50%     66.00000      70.000000      69.000000
# std     15.16308      14.600192      15.195657
#
#       math_score  reading_score  writing_score
#   min	 0.00000 	   17.000000	  10.000000
#
# ### Insight
# - All score means and medians are very close to each other.
# - The standard deviations for all of them are also close, between 14.6 and 15.19
# - The lowest score for math was 0, and the for the other ones were 17 and 10 for reading and writing.

# %%
## Define Numerical and Categorical columns
## Not equal to object
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']

## Is equal to object
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('There are  {} numerical features: {}'.format(len(numeric_features), numeric_features))
print('\nThere are {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# There are  3 numerical features: ['math_score', 'reading_score', 'writing_score']
#
# There are 5 categorical features : ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']

# %%
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

N = len(df['math_score'])
x = df['math_score']
bins = np.arange(0, 9, N)

kde = stats.gaussian_kde(x)
xx= np.linspace(0, 9, 1000)
fig, ax = plt.subplots(figsize=(8,6))
ax.hist(x, density=True, bins=bins, alpha=0.4, color='blue')
ax.plot(xx, kde(xx))
plt.title("KDE Plot for math_score")
plt.show()

# %%
#max_bin_value_math_score=ax[0].hist(x=df['math_score'].values, bins=10)[0].max()
#max_bin_value_reading_score=ax[1].hist(x=df['reading_score'].values, bins=10)[0].max()
#max_bin_value_writing_score=ax[2].hist(x=df['writing_score'].values, bins=10)[0].max()


fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(8,6))
ax[0].hist(x=df['math_score'].values, bins=10)
ax[1].hist(x=df['reading_score'].values, bins=10)
ax[2].hist(x=df['writing_score'].values, bins=10)

#ax[0].vlines(x=df['math_score'].mean(),ymin=0,ymax=max_bin_value_math_score, color='tab:orange')
#ax[1].vlines(x=df['reading_score'].mean(),ymin=0,ymax=max_bin_value_math_score, color='tab:orange')
#ax[2].vlines(x=df['writing_score'].mean(),ymin=0,ymax=max_bin_value_math_score, color='tab:orange')


ax[0].set_title("math_score")
ax[1].set_title("reading_score")
ax[2].set_title("writing_score")
#plt.title("Scores")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/1l/qzn1l5vs497g0fs6wn2b862m0000gn/T/ipykernel_13155/3465855401.py:20: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# * Creating total_score Adding sum of all scores in total score
# * Creating another column that calculates the mean (of the three scores) for each row

# %%
print(df.head(2))
#df.columns
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
########### using Lambda Function
df['total_scores_lambda_01'] = df[["math_score","reading_score","writing_score"]].apply(lambda row: sum(row), axis=1)

###########  using Lambda Function
df['total_scores_lambda_02'] = df.apply(lambda row: row["math_score"] + row["reading_score"] + row["writing_score"], axis=1)

###########  Using map to apply the sum_scores function to each row
def sum_scores(row):
    return row["math_score"] + row["reading_score"] + row["writing_score"]

#sum_scores(df)
rows_list = df.to_dict(orient='records')
#rows_list = df.to_dict('index')
#rows_list[0]['math_score']
df['total_scores_map_01'] = list(map(sum_scores, rows_list))
#print(total_scores_map_01)


df['average_score_lambda'] = df.apply(lambda row: (row["math_score"] + row["reading_score"] + row["writing_score"])/3, axis=1)

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average  total_scores_lambda_01  total_scores_lambda_02  \
# 0          218  72.666667                     218                     218
# ...

# %%
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    total_score    average  total_scores_lambda_01  total_scores_lambda_02  \
# 0          218  72.666667                     218                     218
# 1          247  82.333333                     247                     247
#
#    total_scores_map_01  average_score_lambda
# 0                  218             72.666667
# 1                  247             82.333333

# %%
df['total_score'] = df['math_score'] + df['reading_score'] + df['writing_score']
#df['average_01'] = (df['math_score'] + df['reading_score'] + df['writing_score'])/3
df['average'] = df['total_score']/3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average  total_scores_lambda_01  total_scores_lambda_02  \
# 0          218  72.666667                     218                     218
# ...

# %%
df = df.drop(columns=['total_scores_lambda_01','total_scores_lambda_02','total_scores_map_01','average_score_lambda'],axis=1)
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333

# %%
df.head(2)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333

# %%
df[df['math_score'] == 100].count()
# Out:
# gender                         7
# race_ethnicity                 7
# parental_level_of_education    7
# lunch                          7
# test_preparation_course        7
# math_score                     7
# reading_score                  7
# writing_score                  7
# total_score                    7
# average                        7
# dtype: int64

# %%
df[df['math_score'] == 100]['average'].count()
# Out:
# 7

# %%
## Getting the quantity of students whose average scores average score number of students who had 100
math_full = df[df['math_score'] == 100]['average'].count()
reading_full = df[df['reading_score'] == 100]['average'].count()
writing_full = df[df['writing_score'] == 100]['average'].count()
#math_full

print(f'Number of students with full marks in Maths: {math_full}')
print(f'Number of students with full marks in Writing: {writing_full}')
print(f'Number of students with full marks in Reading: {reading_full}')
# Out:
# Number of students with full marks in Maths: 7
# Number of students with full marks in Writing: 14
# Number of students with full marks in Reading: 17

# %%
## Getting the quantity of students whose average scores average score number of students who had 100
math_less_20 = df[df['math_score'] <= 20]['average'].count()
reading_less_20 = df[df['reading_score'] <= 20]['average'].count()
writing_less_20 = df[df['writing_score'] <= 20]['average'].count()
#math_full

print(f'Number of students with less than 20 marks in Maths: {math_less_20}')
print(f'Number of students with less than 20 marks in Writing: {reading_less_20}')
print(f'Number of students with less than 20 marks in Reading: {writing_less_20}')
# Out:
# Number of students with less than 20 marks in Maths: 4
# Number of students with less than 20 marks in Writing: 1
# Number of students with less than 20 marks in Reading: 3

# %% [markdown]
# ## Insights
# From the values above we can see that there were less students getting a math score of 100%; The number of students getting a 100% score were less in math, then in writing, and then in reading.
#
# The number of students who got a bad score (less than 20%) were more in math, then in reading. The number of students who got a bas score in writing was only one.
#
# The best performance was in reading score section, with an quantity of students of 17.
# The worst performance was in the math score with 4 students getting less than 20%.

# %% [markdown]
# ## EDA Visualization

# %% [markdown]
# ### Visualize Average score distribution
# * Histogram
# * KDE Kernel Distribution Function

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,8))
plt.subplot(121)
sns.histplot(data=df, x='average', bins=30, kde=True, color='tab:green')
plt.subplot(122)
sns.histplot(data=df, x='average',bins=30, kde=True, hue='gender',color='tab:blue')
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total_score', 'average'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(14,10))
#plt.subplot(111)
sns.histplot(data=df, x='average', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[0][0])
axes[0][0].vlines(x=70, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
#plt.subplot(122)
sns.histplot(data=df, x='average', bins=30, kde=True,hue='race_ethnicity', color='tab:blue', alpha=0.4, ax=axes[0][1])
axes[0][1].vlines(x=70, ymin=0, ymax=40, linestyles='--', color='black', linewidth=2)
#plt.subplot(133)
sns.histplot(data=df, x='average', bins=30, kde=True,hue='parental_level_of_education', color='tab:blue', alpha=0.4, ax=axes[0][2])
axes[0][2].vlines(x=70, ymin=0, ymax=40, linestyles='--', color='black', linewidth=2)
#plt.subplot(231)
sns.histplot(data=df, x='average', bins=30, kde=True,hue='lunch', color='tab:blue', alpha=0.4, ax=axes[1][0])
axes[1][0].vlines(x=70, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
#plt.subplot(232)
sns.histplot(data=df, x='average', bins=30, kde=True,hue='test_preparation_course', color='tab:blue', alpha=0.4, ax=axes[1][1])
axes[1][1].vlines(x=70, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)

plt.suptitle("Average Score Comparison between other features")
plt.tight_layout()
plt.show()
## Female students have an average better performance than male students.
## Group E have an average better performance
## Students who had lunch before the exam had a better performance
## Students who completed the course were less but had a better average score than those who did not

# %% [markdown]
# ## Visualization using Total Score Instead of Average Score

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,8))
plt.subplot(121)
sns.histplot(data=df, x='total_score', bins=30, kde=True, color='tab:green')
plt.subplot(122)
sns.histplot(data=df, x='total_score',bins=30, kde=True, hue='gender',color='tab:blue')
plt.title("Total score comparison between Gender")
plt.suptitle("Total Score")
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(14,10))
#plt.subplot(111)
sns.histplot(data=df, x='total_score', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[0][0])
#axes[0][0].vlines(x=70*3, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
#plt.subplot(122)
sns.histplot(data=df, x='total_score', bins=30, kde=True,hue='race_ethnicity', color='tab:blue', alpha=0.4, ax=axes[0][1])
#axes[0][1].vlines(x=70*3, ymin=0, ymax=40, linestyles='--', color='black', linewidth=2)
#plt.subplot(133)
sns.histplot(data=df, x='total_score', bins=30, kde=True,hue='parental_level_of_education', color='tab:blue', alpha=0.4, ax=axes[0][2])
#axes[0][2].vlines(x=70*3, ymin=0, ymax=40, linestyles='--', color='black', linewidth=2)
#plt.subplot(231)
sns.histplot(data=df, x='total_score', bins=30, kde=True,hue='lunch', color='tab:blue', alpha=0.4, ax=axes[1][0])
#axes[1][0].vlines(x=70*3, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
#plt.subplot(232)
sns.histplot(data=df, x='total_score', bins=30, kde=True,hue='test_preparation_course', color='tab:blue', alpha=0.4, ax=axes[1][1])
#axes[1][1].vlines(x=70*3, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)

plt.suptitle("Average Score Comparison between Dataset features")
plt.tight_layout()
plt.show()
## Female students have an average better performance than male students.
## Group E have an average better performance
## Students who had lunch before the exam had a better performance
## Students who completed the course were less but had a better average score than those who did not

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(14,10))
#plt.subplot(111)
sns.histplot(data=df, x='average', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[0][0])
#axes[0][0].vlines(x=70*3, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
axes[0][0].set_title("Average Score Comparison between genders")
#plt.subplot(122)
sns.histplot(data=df, x='total_score', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[0][1])
#axes[0][1].vlines(x=70*3, ymin=0, ymax=40, linestyles='--', color='black', linewidth=2)
axes[0][1].set_title("Total Score Comparison between genders")
#plt.subplot(133)
sns.histplot(data=df, x='math_score', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[0][2])
#axes[0][2].vlines(x=70*3, ymin=0, ymax=40, linestyles='--', color='black', linewidth=2)
axes[0][2].set_title("Math Score Comparison between genders")
#plt.subplot(231)
sns.histplot(data=df, x='reading_score', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[1][0])
#axes[1][0].vlines(x=70*3, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
axes[1][0].set_title("Reading Score Comparison between genders")
#plt.subplot(232)
sns.histplot(data=df, x='writing_score', bins=30, kde=True,hue='gender', color='tab:blue', alpha=0.4, ax=axes[1][1])
#axes[1][1].vlines(x=70*3, ymin=0, ymax=60, linestyles='--', color='black', linewidth=2)
axes[1][1].set_title("Writing Score Comparison between genders")

plt.suptitle("Score Comparison between Gender")
plt.tight_layout()
plt.show()
## Female students have an average better performance than male students.
## Group E have an average better performance
## Students who had lunch before the exam had a better performance
## Students who completed the course were less but had a better average score than those who did not

# %% [markdown]
# ## Insights
#
# * Female students have an average better performance than male students.
# * Group E have an average better performance
# * Students who had lunch before the exam had a better performance
# * Students who completed the course were less but had a better average score than those who did not
#
# Females tend to perform better than male students
#
# Females performed better at writing and reading.
# Males performed slightly better than females in math scores

# %%
plt.subplots(nrows=1,ncols=3,figsize=(20,6))
plt.subplot(131)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.title("Average Score Comparison between genders")
plt.subplot(132)
#sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
sns.histplot(data=df[df['gender']=='female'],x='average',kde=True,hue='lunch')
plt.title("Average Score Comparison for Female Gender")
plt.subplot(133)
sns.histplot(data=df[df['gender']=='male'],x='average',kde=True,hue='lunch')
plt.title("Average Score Comparison for Male Gender")
plt.show()

## There were more standard lunches than free/reduced.
## Students who had lunch before taking the exam in general had a better performance
## In General, for Male and Female students who had lunch before taking the exam in general had a better performance

# %% [markdown]
# ### Insights
# * In general, standard lunch helps perform well in exams, for both, female and male students.

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total_score', 'average'],
#       dtype='object')

# %%
plt.subplots(1,3,figsize=(30,6))
plt.subplot(131)
ax =sns.histplot(data=df,x='average',kde=True,hue='parental_level_of_education')
plt.subplot(132)
ax =sns.histplot(data=df[df['gender']=='male'],x='average',kde=True,hue='parental_level_of_education')
plt.subplot(133)
ax =sns.histplot(data=df[df['gender']=='female'],x='average',kde=True,hue='parental_level_of_education')
plt.tight_layout()
plt.show()

## parental_level_of_education does not seem to have a great effect on the student's performance

# %% [markdown]
# #####  Insights
# - In general parent's education don't seem to help students perform well in the exams.
# - (2nd plot) - Male students who have parents whose level of education is of Associate's or master's degree seem to have a better performance.
# - (2nd plot) - Female student's parents degree of education does not seem to have an effect on performance.

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(131)
ax =sns.histplot(data=df,x='average',kde=True,hue='race_ethnicity')
plt.subplot(132)
ax =sns.histplot(data=df[df['gender']=='female'],x='average',kde=True,hue='race_ethnicity')
plt.subplot(133)
ax =sns.histplot(data=df[df['gender']=='male'],x='average',kde=True,hue='race_ethnicity')
plt.show()

# %% [markdown]
# Insights
# * Students from group A and B performed poorly in the exams, irrespectively of whether they are male or female.

# %% [markdown]
# ### Maximum Score of students in all three subjects

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total_score', 'average'],
#       dtype='object')

# %%
#plt.figure(figsize=(14,8))
#plt.subplot(1, 3, 1)
#plt.title("Math Scores")
#sns.violinplot(data=df, y='math_score', color='tab:orange', linewidth=3)
#plt.subplot(1, 3, 2)
#plt.title("Reading Scores")
#sns.violinplot(data=df, y='reading_score', color='tab:green', linewidth=3)
#plt.subplot(1, 3, 3)
#plt.title("Writing Scores")
#sns.violinplot(data=df, y='writing_score', color='tab:blue', linewidth=3)
#plt.tight_layout()
#plt.show()


plt.subplots(1,3,figsize=(14,8))
plt.subplot(131)
sns.violinplot(data=df, y='math_score', color='tab:orange', linewidth=3)
plt.title("Math Scores")
plt.subplot(132)
sns.violinplot(data=df, y='reading_score', color='tab:green', linewidth=3)
plt.title("Reading Scores")
plt.subplot(133)
sns.violinplot(data=df, y='writing_score', color='tab:blue', linewidth=3)
plt.title("Writing Scores")
plt.show()

# %% [markdown]
# Insights
# Most of the students math scores lie between 60 and 80; For the Reading and Writing scores most of them are located between 50 and 80.
# There is higher density for the math scores at around 60-70 and for Reading and writing at around 70
# There are some outliers on all scores, especially on the lower side of the distribution.
# The median for the math score lies in around 60 and 70, while the median for Reading and Writing seems to be around 70. Meaning that half of the students got a lower score in math

# %% [markdown]
# ### Mutivariate Analysis using Pie Plott

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total_score', 'average'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['tab:red','tab:green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['race_ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['tab:red', 'tab:green', 'tab:blue', 'tab:cyan','tab:orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race/Ethnicity', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['tab:red','tab:green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['test_preparation_course'].value_counts()
labels = 'None', 'Completed'
color = ['tab:red','tab:green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 5)
size = df['parental_level_of_education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['tab:red', 'tab:green', 'tab:blue', 'tab:cyan','tab:orange','tab:grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# #####  Insights
# - Number of Male and Female students is almost equal
# - Number students are greatest in Group C and less in group A
# - Most students had standard lunch
# - Number of students who have not enrolled in any test preparation course is greater
# - Number of students whose parental education is "Some College" is greater followed closely by "Associate's Degree", very few of the parents had a master's degree

# %% [markdown]
# ## Feature Wise Visualization

# %% [markdown]
# ### Gender Column
#
# - Gender Distribution
# - Does gender seems to have an impact on student's performance?

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
sns.countplot(data=df, x=df['gender'], palette='muted',hue='gender', saturation=0.95, ax=axes[0])
for container in axes[0].containers:
    axes[0].bar_label(container, color='black', size=20)

## Error on the pie chart. Describing that there are more males than females
##plt.pie(data=df, x=df['gender'].value_counts(), labels=['Male', 'Female'], explode=[0, 0.05],
#        autopct='%1.1f%%', shadow=True, colors=['#3488d7','#af1e89'])
plt.pie(data=df, x=df['gender'].value_counts(), labels=['Female', 'Male'], explode=[0, 0.05],
        autopct='%1.1f%%', shadow=True, colors=['#3488d7','#af1e89'])

#plt.pie(x=df['gender'].value_counts(),labels=['Male','Female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])

axes[0].legend()
axes[1].legend()

plt.tight_layout()

plt.show()
# Out:
# /var/folders/1l/qzn1l5vs497g0fs6wn2b862m0000gn/T/ipykernel_13155/2791673142.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()

# %% [markdown]
# ### Insights
# There are 518 female students, corresponding to the 52%.
# There are 482 male students which correspond to the 48%

# %% [markdown]
# # Go to Project_EDA_002_001.ipynb
